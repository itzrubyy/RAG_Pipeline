# %% [markdown]
# <a href="https://colab.research.google.com/github/itzrubyy/RAG_Pipeline/blob/main/exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install together langchain langchain_community unstructured sentence_transformers

# %%
# !pip install InstructorEmbedding

# %%
# !pip uninstall sentence-transformers
# Out:
# Found existing installation: sentence-transformers 2.2.2
# Uninstalling sentence-transformers-2.2.2:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/sentence_transformers-2.2.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/sentence_transformers/*
# Proceed (Y/n)? Y
#   Successfully uninstalled sentence-transformers-2.2.2

# %%
# !pip install sentence-transformers==2.2.2
# Out:
# ...
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# ...

# %%
import together
from langchain.prompts import PromptTemplate
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceInstructEmbeddings
from langchain_community.vectorstores import Chroma
from sentence_transformers import SentenceTransformer

# %%
from huggingface_hub import login

login(token="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")

together.api_key = "4eb4a7daeb3f2fb70e2b6a7232db2a4c6d78de62be46b0a1d3c786b1eecd4c57"
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
urls = ["https://www.moneycontrol.com/stocksmarketsindia/"]

# %%
loader = UnstructuredURLLoader(urls=urls)

documents = loader.load()

print(f"You have {len(documents)} documents in your data")
# Out:
# You have 1 documents in your data

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)

texts = text_splitter.split_documents(documents)

print(f"Now you have {len(texts)} documents")
# Out:
# Now you have 40 documents

# %%
embeddings = HuggingFaceInstructEmbeddings(
    model_name='hkunlp/instructor-xl',
    model_kwargs={'device': 'cpu'}, # Remove 'token' if it exists in this dictionary
    encode_kwargs={'normalize_embeddings': True}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 110.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
db = Chroma.from_documents(texts, embeddings)

# %%
query = "What is the price of Bitcoin?"

docs = db.similarity_search(query, k=4)

print(docs)
# Out:
# [Document(metadata={'source': 'https://www.moneycontrol.com/stocksmarketsindia/'}, page_content='Sectoral Indices\n\nOther Indices\n\nOnly one index can be selected at a time\n\nUS Stock Action\n\nTop Gainers\n\nDow Jones\n\n1 Day\n\n1 Day\n\n1 Week\n\n1 Month\n\n3 Month\n\n6 Month\n\nYTD\n\n1 Year\n\n2 Year\n\n3 Year\n\nCompany Current % Gain No Gainers for today\n\nView More\n\nTop Losers\n\nDow Jones\n\n1 Day\n\n1 Day\n\n1 Week\n\n1 Month\n\n3 Month\n\n6 Month\n\nYTD\n\n1 Year\n\n2 Year\n\n3 Year\n\nCompany Current($) % Loss Intel 20.12 -6.11 Apple 209.27 -4.56 Cisco Systems 44.77 -4.01 Amazon 160.97 -3.97 Visa 256.43 -3.70\n\nView More\n\n52 Week High\n\n52 Week Low\n\nDow Jones\n\n1 Day\n\n1 Week\n\n1 Month\n\n3 Month\n\n6 Month\n\nYTD\n\n1 Year\n\n2 Year\n\n3 Year\n\nCompany Days High Current Coca-Cola 69.67 68.14 UnitedHealth 590.33 570.28\n\nView More\n\nDow Jones\n\n1 Day\n\n1 Week\n\n1 Month\n\n3 Month\n\n6 Month\n\nYTD\n\n1 Year\n\n2 Year\n\n3 Year\n\nCompany Days Low Curr
# ...

# %%
from langchain.chains import RetrievalQA
from langchain.llms.base import LLM
from pydantic import Field

class LLAMA(LLM):
    model_name: str = Field()
    temperature: float = Field(default=0.4)

    def __init__(self, model, temperature=0.4):
        super().__init__(model_name=model, temperature=temperature)

    def _call(self, prompt, stop=None):
        output = together.Complete.create(
            prompt=prompt,
            model=self.model_name,  # Use model_name here
            temperature=self.temperature,
        )
        return output["choices"][0]["text"]

    @property
    def _llm_type(self):
        return "custom"

# %%
llm = LLAMA(model="togethercomputer/llama-2-70b-chat", temperature=0.5)

retriever = db.as_retriever()

# %%
rag = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

# %%
import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

def process_llm_response(llm_response):
    print(wrap_text_preserve_newlines(llm_response['result']))
    print('\n\nSources:')
    print(f"llm_response :{llm_response}")
    # for source in llm_response["source_documents"]:
    #     print(source.metadata['source'])

# %%
query = "Current stock price of Tesla ?"
llm_response = rag(query)
process_llm_response(llm_response)
# Out:
# <ipython-input-30-3b0a888ebe15>:13: DeprecationWarning: Call to deprecated function create.
#   output = together.Complete.create(
# /usr/local/lib/python3.10/dist-packages/together/legacy/complete.py:23: UserWarning: The use of together.api_key is deprecated and will be removed in the next major release. Please set the TOGETHER_API_KEY environment variable instead.
#   warnings.warn(API_KEY_WARNING)
#  I don't know.
#
# Please select one of the following options:
#
# A) 20.12
# B) 209.27
# C) 44.77
# D) 160.97
# E) 256.43
# Please select one of the following options:
#
# A) 20.12
# B) 209.27
# C) 44.77
# D) 160.97
# E) 256.43
#
#
# Sources:
# llm_response :{'query': 'Current stock price of Tesla ?', 'result': " I don't know.\n\nPlease select one of the following options:\n\nA) 20.12\nB) 209.27\nC) 44.77\nD) 160.97\nE) 256.43\nPlease select one of the following options:\n\nA) 20.12\nB) 209.27\nC) 44.77\nD) 160.97\nE) 256.43"}
